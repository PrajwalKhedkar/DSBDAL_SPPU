# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cea6d2b8-9955-44f4-8e54-15477e9cbb46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cea6d2b8-9955-44f4-8e54-15477e9cbb46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience   Age  Salary
# 0               1.1  21.0   39343
# 1               1.3  21.5   46205
# 2               1.5  21.7   37731
# 3               2.0  22.0   43525
# 4               2.2  22.2   39891
# 5               2.9  23.0   56642
# 6               3.0  23.0   60150
# 7               3.2  23.3   54445
# 8               3.2  23.3   64445
# 9               3.7  23.6   57189
# 10              3.9  23.9   63218
# 11              4.0  24.0   55794
# 12              4.0  24.0   56957
# 13              4.1  24.0   57081
# 14              4.5  25.0   61111
# 15              4.9  25.0   67938
# 16              5.1  26.0   66029
# 17              5.3  27.0   83088
# 18              5.9  28.0   81363
# 19              6.0  29.0   93940
# 20              6.8  30.0   91738
# 21              7.1  30.0   98273
# 22              7.9  31.0  101302
# 23              8.2  32.0  113812
# 24              8.7  33.0  109431
# 25              9.0  34.0  105582
# ...

# %% [markdown]
# Mean

# %%
df.mean() #mean of each column
# Out:
# YearsExperience        5.313333
# Age                   27.216667
# Salary             76003.000000
# dtype: float64

# %%
df.loc[:,'Age'].mean() #mean of SepalLengthCm
# Out:
# 27.216666666666665

# %%
df.mean(axis=1)[0:2] #mean of rows 0 and 1
# Out:
# 0    13121.700000
# 1    15409.266667
# dtype: float64

# %% [markdown]
# Median

# %%
df.median()
# Out:
# YearsExperience        4.7
# Age                   25.0
# Salary             65237.0
# dtype: float64

# %%
df.loc[:,'Salary'].median()
# Out:
# 65237.0

# %%
df.median(axis=1)[1:2]
# Out:
# 1    21.5
# dtype: float64

# %% [markdown]
# Mode

# %%
df.mode()
# Out:
#     YearsExperience   Age  Salary
# 0               3.2  24.0   37731
# 1               4.0   NaN   39343
# 2               NaN   NaN   39891
# 3               NaN   NaN   43525
# 4               NaN   NaN   46205
# 5               NaN   NaN   54445
# 6               NaN   NaN   55794
# 7               NaN   NaN   56642
# 8               NaN   NaN   56957
# 9               NaN   NaN   57081
# 10              NaN   NaN   57189
# 11              NaN   NaN   60150
# 12              NaN   NaN   61111
# 13              NaN   NaN   63218
# 14              NaN   NaN   64445
# 15              NaN   NaN   66029
# 16              NaN   NaN   67938
# 17              NaN   NaN   81363
# 18              NaN   NaN   83088
# 19              NaN   NaN   91738
# 20              NaN   NaN   93940
# 21              NaN   NaN   98273
# 22              NaN   NaN  101302
# 23              NaN   NaN  105582
# 24              NaN   NaN  109431
# 25              NaN   NaN  112635
# ...

# %%
df.loc[:,'Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %% [markdown]
# Minimun

# %%
df.min()
# Out:
# YearsExperience        1.1
# Age                   21.0
# Salary             37731.0
# dtype: float64

# %%
df.min(axis =1)[2:5]
# Out:
# 2    1.5
# 3    2.0
# 4    2.2
# dtype: float64

# %% [markdown]
# Maximun

# %%
df.max()
# Out:
# YearsExperience        10.5
# Age                    38.0
# Salary             122391.0
# dtype: float64

# %%
df.loc[:,'Salary'].max()
# Out:
# 122391

# %% [markdown]
# Standard deviation

# %%
df.std()
# Out:
# <ipython-input-23-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
df.loc[:,'Age'].std()
# Out:
# 5.161267108077196

# %%
df.std(axis=1)[0:2]
# Out:
# <ipython-input-28-2d00bb86555b>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std(axis=1)[0:2]
# 0    2.010721
# 1    1.772005
# dtype: float64

# %% [markdown]
# Group By

# %%
df.groupby(['Salary'])['Age'].mean() # grouping by Petal width mean of sepal width is taken
# Out:
# Salary
# 37731     21.7
# 39343     21.0
# 39891     22.2
# 43525     22.0
# 46205     21.5
# 54445     23.3
# 55794     24.0
# 56642     23.0
# 56957     24.0
# 57081     24.0
# 57189     23.6
# 60150     23.0
# 61111     25.0
# 63218     23.9
# 64445     23.3
# 66029     26.0
# 67938     25.0
# 81363     28.0
# 83088     27.0
# 91738     30.0
# 93940     29.0
# 98273     30.0
# 101302    31.0
# 105582    34.0
# 109431    33.0
# 112635    36.0
# 113812    32.0
# 116969    35.0
# 121872    38.0
# 122391    37.0
# Name: Age, dtype: float64

# %% [markdown]
# Section B

# %%
iris=pd.read_csv("Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
irisSet = (iris['Species']== 'Iris-setosa')

# %%
print("Iris Setosa")
print(iris[irisSet].describe())
# Out:
# Iris Setosa
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
irisVer = (iris['Species']== 'Iris-versicolor')

# %%
print("Iris versicolor")
print(iris[irisVer].describe())
# Out:
# Iris versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
irisvir = (iris['Species']== 'Iris-virginica')

# %%
print("Iris virginica")
print(iris[irisvir].describe())
# Out:
# Iris virginica
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000
