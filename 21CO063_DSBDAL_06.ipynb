# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
cnf=data

# %%
cnf.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
cnf.boxplot()
# Out:
# <Axes: >

# %%
X=cnf.drop(['Species'],axis=1)
Y=cnf['Species']

# %%
from sklearn.model_selection import train_test_split
xtre,xtes,ytre,ytes=train_test_split(X,Y,test_size=2,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
model=gnb.fit(xtre,ytre)
model
# Out:
# GaussianNB()

# %%
ypred=gnb.predict(xtes)

# %%
xtre
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 33    34            5.5           4.2            1.4           0.2
# 107  108            7.3           2.9            6.3           1.8
# 7      8            5.0           3.4            1.5           0.2
# 100  101            6.3           3.3            6.0           2.5
# 40    41            5.0           3.5            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 9     10            4.9           3.1            1.5           0.1
# 103  104            6.3           2.9            5.6           1.8
# 67    68            5.8           2.7            4.1           1.0
# 117  118            7.7           3.8            6.7           2.2
# 47    48            4.6           3.2            1.4           0.2
#
# [148 rows x 5 columns]

# %%
ytre
# Out:
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# 100     Iris-virginica
# 40         Iris-setosa
#             ...
# 9          Iris-setosa
# 103     Iris-virginica
# 67     Iris-versicolor
# 117     Iris-virginica
# 47         Iris-setosa
# Name: Species, Length: 148, dtype: object

# %%
xtes
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114  115            5.8           2.8            5.1           2.4
# 62    63            6.0           2.2            4.0           1.0

# %%
ytes
# Out:
# 114     Iris-virginica
# 62     Iris-versicolor
# Name: Species, dtype: object

# %%
ypred
# Out:
# array(['Iris-virginica', 'Iris-versicolor'], dtype='<U15')

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, precision_score, recall_score, f1_score,classification_report

# %%
cm=confusion_matrix(ytes,ypred)
cm
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
tp=cm[1,1]
fp=cm[0,1]
tn=cm[1,0]
fn=cm[0,0]

# %%
ps=precision_score(ytes,ypred,average='micro')
ps
# Out:
# 1.0

# %%
rs=recall_score(ytes,ypred,average='micro')
rs
# Out:
# 1.0

# %%
acc=accuracy_score(ytes,ypred)
acc
# Out:
# 1.0

# %%
fs=f1_score(ytes,ypred,average='micro')
fs
# Out:
# 1.0

# %%
error_rate=1-acc
error_rate
# Out:
# 0.0

# %%
tp
# Out:
# 1

# %%
fp
# Out:
# 0

# %%
tn
# Out:
# 0

# %%
fn
# Out:
# 1

# %%
cr=classification_report(ytes,ypred)
cr
# Out:
# '                 precision    recall  f1-score   support\n\nIris-versicolor       1.00      1.00      1.00         1\n Iris-virginica       1.00      1.00      1.00         1\n\n       accuracy                           1.00         2\n      macro avg       1.00      1.00      1.00         2\n   weighted avg       1.00      1.00      1.00         2\n'
